# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_data_path = '../data/raw/'
test_data = pd.read_csv(raw_data_path + 'AH_DL_60_12_1_2.csv', header=None, index_col=0)
test_data.plot(figsize=(20,12))

# %%
test_data
# Out:
#                0     1     2     3     4     5     6      7      8
# 0     6429590.12 -0.70  0.74  1.53  0.18  0.92 -4.83  44.54   1.45
# 1     6429670.12 -0.70  0.74  1.59  0.18  0.92 -4.83  44.54   1.45
# 2     6429750.12 -0.70  0.74  1.53  0.06  1.04 -4.83  44.54   1.45
# 3     6429830.12 -0.70  0.74  1.71  0.06  1.10 -4.83  44.54   1.45
# 4     6429910.12 -0.70  0.74  1.65  0.06  1.04 -4.83  44.54   1.45
# ...          ...   ...   ...   ...   ...   ...   ...    ...    ...
# 6738  6979050.21 -0.99 -0.19 -3.91 -0.85  1.40 -8.23  51.75  34.86
# 6739  6979130.21 -0.99 -0.20 -3.60 -0.92  1.40 -8.23  51.75  34.86
# 6740  6979220.20 -0.98 -0.22 -3.60 -1.04  1.22 -8.20  51.78  34.05
# 6741  6979310.20 -0.97 -0.23 -3.42 -0.98  1.10 -8.20  51.78  34.05
# 6742  6979390.20 -0.99 -0.22 -2.75 -0.67  1.28 -8.20  51.78  34.05
#
# [6743 rows x 9 columns]
